# %% [markdown]
# # **Modelo preditivo para sucesso de start-ups**

# %% [markdown]
# ### **Importando bibliotecas importantes**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Importando os dados**

# %%
df = pd.read_csv('../data/train.csv')
df.head(30)
# Out:
#      id  age_first_funding_year  age_last_funding_year  \
# 0   719                   10.42                  13.09
# 1   429                    3.79                   3.79
# 2   178                    0.71                   2.28
# 3   197                    3.00                   5.00
# 4   444                    0.66                   5.88
# 5    67                    1.09                   1.09
# 6   505                    0.65                   0.65
# 7   410                    0.34                   5.22
# 8   284                    0.00                   0.00
# 9   252                    0.08                   4.33
# 10  324                    0.75                   3.07
# 11  105                     NaN                   1.25
# 12  673                    1.28                   2.01
# 13  749                    0.00                   0.00
# 14  211                    2.24                   4.03
# 15  841                    0.00                   0.00
# ...

# %% [markdown]
# ### **Exploração de dados**

# %% [markdown]
# Cada start-up registrada no banco de dados só aparece uma vez, e as informações de cada uma estão distribuidas nas colunas. São 646 start-ups.

# %%
numero_de_linhas = len(df)
print(f"O DataFrame tem {numero_de_linhas} linhas.")
# Out:
# O DataFrame tem 646 linhas.

# %% [markdown]
# ### **Pre-processamento**: limpeza e transformação de dados
